# %%
text = """
동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
남산 위에 저 소나무 철갑을 두른 듯
바람 서리 불변함은 우리 기상일세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
가을 하늘 공활한데 높고 구름 없이
밝은 달은 우리 가슴 일편단심일세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세
이 기상과 이 맘으로 충성을 다하여
괴로우나 즐거우나 나라 사랑하세
무궁화 삼천리 화려 강산
대한 사람 대한으로 길이 보전하세"""
text = text * 10
print(text)
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 남산 위에 저 소나무 철갑을 두른 듯
# 바람 서리 불변함은 우리 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 가을 하늘 공활한데 높고 구름 없이
# 밝은 달은 우리 가슴 일편단심일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 이 기상과 이 맘으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 남산 위에 저 소나무 철갑을 두른 듯
# 바람 서리 불변함은 우리 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 가을 하늘 공활한데 높고 구름 없이
# 밝은 달은 우리 가슴 일편단심일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 이 기상과 이 맘으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 남산 위에 저 소나무 철갑을 두른 듯
# 바람 서리 불변함은 우리 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 가을 하늘 공활한데 높고 구름 없이
# 밝은 달은 우리 가슴 일편단심일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 이 기상과 이 맘으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 남산 위에 저 소나무 철갑을 두른 듯
# 바람 서리 불변함은 우리 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 가을 하늘 공활한데 높고 구름 없이
# 밝은 달은 우리 가슴 일편단심일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 이 기상과 이 맘으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 남산 위에 저 소나무 철갑을 두른 듯
# 바람 서리 불변함은 우리 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 가을 하늘 공활한데 높고 구름 없이
# 밝은 달은 우리 가슴 일편단심일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 이 기상과 이 맘으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 남산 위에 저 소나무 철갑을 두른 듯
# 바람 서리 불변함은 우리 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 가을 하늘 공활한데 높고 구름 없이
# 밝은 달은 우리 가슴 일편단심일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 이 기상과 이 맘으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 남산 위에 저 소나무 철갑을 두른 듯
# 바람 서리 불변함은 우리 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 가을 하늘 공활한데 높고 구름 없이
# 밝은 달은 우리 가슴 일편단심일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 이 기상과 이 맘으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 남산 위에 저 소나무 철갑을 두른 듯
# 바람 서리 불변함은 우리 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 가을 하늘 공활한데 높고 구름 없이
# 밝은 달은 우리 가슴 일편단심일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 이 기상과 이 맘으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 남산 위에 저 소나무 철갑을 두른 듯
# 바람 서리 불변함은 우리 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 가을 하늘 공활한데 높고 구름 없이
# 밝은 달은 우리 가슴 일편단심일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 이 기상과 이 맘으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 남산 위에 저 소나무 철갑을 두른 듯
# 바람 서리 불변함은 우리 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 가을 하늘 공활한데 높고 구름 없이
# 밝은 달은 우리 가슴 일편단심일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세
# 이 기상과 이 맘으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하세

# %%
# 문자 집합 생성
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(chars)
print(vocab_size)

# 문자 ↔ 인덱스 매핑
char2idx = {ch: i for i, ch in enumerate(chars)}
idx2char = {i: ch for i, ch in enumerate(chars)}

print(char2idx)
print(idx2char)
# Out:
# ['\n', ' ', '가', '갑', '강', '거', '고', '공', '과', '괴', '구', '궁', '기', '길', '나', '남', '높', '느', '늘', '님', '다', '단', '달', '닳', '대', '데', '도', '동', '두', '듯', '라', '람', '랑', '려', '로', '록', '르', '른', '름', '리', '마', '만', '맘', '무', '물', '바', '밝', '백', '변', '보', '불', '사', '산', '삼', '상', '서', '성', '세', '소', '슴', '심', '없', '에', '여', '우', '위', '으', '은', '을', '이', '일', '저', '전', '즐', '천', '철', '충', '편', '하', '한', '함', '해', '화', '활']
# 84
# {'\n': 0, ' ': 1, '가': 2, '갑': 3, '강': 4, '거': 5, '고': 6, '공': 7, '과': 8, '괴': 9, '구': 10, '궁': 11, '기': 12, '길': 13, '나': 14, '남': 15, '높': 16, '느': 17, '늘': 18, '님': 19, '다': 20, '단': 21, '달': 22, '닳': 23, '대': 24, '데': 25, '도': 26, '동': 27, '두': 28, '듯': 29, '라': 30, '람': 31, '랑': 32, '려': 33, '로': 34, '록': 35, '르': 36, '른': 37, '름': 38, '리': 39, '마': 40, '만': 41, '맘': 42, '무': 43, '물': 44, '바': 45, '밝': 46, '백': 47, '변': 48, '보': 49, '불': 50, '사': 51, '산': 52, '삼': 53, '상': 54, '서': 55, '성': 56, '세': 57, '소': 58, '슴': 59, '심': 60, '없': 61, '에': 62, '여': 63, '우': 64, '위': 65, '으': 66, '은': 67, '을': 68, '이': 69, '일': 70, '저': 71, '전': 72, '즐': 73, '천': 74, '철': 75, '충': 76, '편': 77, '하': 78, '한': 79, '함': 80, '해': 81, '화': 82, '활': 83}
# {0: '\n', 1: ' ', 2: '가', 3: '갑', 4: '강', 5: '거', 6: '고', 7: '공', 8: '과', 9: '괴', 10: '구', 11: '궁', 12: '기', 13: '길', 14: '나', 15: '남', 16: '높', 17: '느', 18: '늘', 19: '님', 20: '다', 21: '단', 22: '달', 23: '닳', 24: '대', 25: '데', 26: '도', 27: '동', 28: '두', 29: '듯', 30: '라', 31: '람', 32: '랑', 33: '려', 34: '로', 35: '록', 36: '르', 37: '른', 38: '름', 39: '리', 40: '마', 41: '만', 42: '맘', 43: '무', 44: '물', 45: '바', 46: '밝', 47: '백', 48: '변', 49: '보', 50: '불', 51: '사', 52: '산', 53: '삼', 54: '상', 55: '서', 56: '성', 57: '세', 58: '소', 59: '슴', 60: '심', 61: '없', 62: '에', 63: '여', 64: '우', 65: '위', 66: '으', 67: '은', 68: '을', 69: '이', 70: '일', 71: '저', 72: '전', 73: '즐', 74: '천', 75: '철', 76: '충', 77: '편', 78: '하', 79: '한', 80: '함', 81: '해', 82: '화', 83: '활'}

 70, 57, 0, 43, 11, 82, 1, 53, 74, 39, 1, 82, 33, 1, 4, 52, 0, 24, 79, 1, 51, 31, 1, 24, 79, 66, 34, 1, 13, 69, 1, 49, 72, 78, 57, 0, 2, 68, 1, 78, 18, 1, 7, 83, 79, 25, 1, 16, 6, 1, 10, 38, 1, 61, 69, 0, 46, 67, 1, 22, 67, 1, 64, 39, 1, 2, 59, 1, 70, 77, 21, 60, 70, 57, 0, 43, 11, 82, 1, 53, 74, 39, 1, 82, 33, 1, 4, 52, 0, 24, 79, 1, 51, 31, 1, 24, 79, 66, 34, 1, 13, 69, 1, 49, 72, 78, 57, 0, 69, 1, 12, 54, 8, 1, 69, 1, 42, 66, 34, 1, 76, 56, 68, 1, 20, ...

# %%
import torch
import numpy as np

seq_len = 30
X = []
Y = []
for i in range(len(data) - seq_len):
    X.append(data[i:i+seq_len])
    Y.append(data[i+seq_len])

X = torch.tensor(X, dtype=torch.long)
Y = torch.tensor(Y, dtype=torch.long)

print(X.shape)
print(Y.shape)
# Out:
# torch.Size([2820, 30])
# torch.Size([2820])

# %%
import torch.nn as nn

class CharLSTM(nn.Module):
    def __init__(self, vocab_size, hidden_size, num_layers=1):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, vocab_size)

    def forward(self, x, hidden=None):
        x = self.embed(x)               # 정수 시퀀스를 임베딩 벡터로 변환
        out, hidden = self.lstm(x, hidden)
        out = self.fc(out[:, -1])       # 마지막 시점의 은닉 상태만 사용
        return out, hidden

# %%
model = CharLSTM(vocab_size=vocab_size, hidden_size=128)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
def generate_text(model, start_text, length):
    # 모델을 추론 모드로 설정
    model.eval()
    
    # 시작 문자열을 정수 시퀀스로 변환 (배치 차원 추가)
    input_seq = torch.tensor([char2idx[ch] for ch in start_text], dtype=torch.long).unsqueeze(0)
    
    # 생성된 텍스트를 저장할 리스트
    generated = list(start_text)

    # LSTM 초기 은닉 상태
    hidden = None

    # length만큼 반복해서 새로운 문자 생성
    for _ in range(length):
        # 모델 통과 → 다음 글자 확률 분포 얻기
        output, hidden = model(input_seq, hidden)

        # softmax로 확률 분포 계산
        probs = nn.functional.softmax(output, dim=-1).squeeze()

        # 확률 분포에 따라 랜덤 샘플링
        next_idx = torch.multinomial(probs, 1).item()
        next_char = idx2char[next_idx]
        generated.append(next_char)

        # 다음 입력 시퀀스 갱신 (맨 앞 제거 + 새 문자 추가)
        input_seq = torch.cat([
            input_seq[:, 1:], 
            torch.tensor([[next_idx]])
        ], dim=1)

    return ''.join(generated)

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib  # 한글 깨짐 방지

n_epochs = 300
loss_history = []  # 에폭별 손실 저장 리스트

for epoch in range(n_epochs):
    model.train()
    optimizer.zero_grad()

    output, _ = model(X)  # output: (batch, vocab_size)
    loss = loss_fn(output, Y)  # 정답 Y와 예측 output을 비교
    loss.backward()
    optimizer.step()

    # 손실 기록
    loss_history.append(loss.item())

    # 주기적으로 출력 (손실 + 샘플 문장 생성)
    if epoch % 20 == 0:
        print(f"Epoch {epoch:3d} | Loss: {loss.item():.4f}")
        
        # 가을 하늘로 시작하는 샘플 생성
        sample = generate_text(model, start_text="가을 하늘 ", length=50)
        print("샘플 생성:", sample)
        print("-" * 80)

# 훈련 후 손실 그래프 시각화
plt.plot(range(n_epochs), loss_history)
plt.xlabel("에폭(epoch)")
plt.ylabel("손실(loss)")
plt.title("훈련 손실 변화")
plt.grid(True)
plt.show()
# Out:
# Epoch   0 | Loss: 4.4439
# 샘플 생성: 가을 하늘 사함철과갑밝과물갑위하함삼기대에가심불슴위세 저밝변님기람보상위길도른보물활강마른데세산른나충느산남
# --------------------------------------------------------------------------------
# Epoch  20 | Loss: 3.1939
# 샘플 생성: 가을 하늘 산   사이전 하강 저마대 세람 세과서리님단한기 을 천사위을하데하 변전하사로
# 두즐세 우저
# --------------------------------------------------------------------------------
# Epoch  40 | Loss: 1.9964
# 샘플 생성: 가을 하늘 삼우리 느 변 충소갑한으으로 로르세리물 변한이은 달길이 사람람 이려 거 록리일없철리 데두충
# --------------------------------------------------------------------------------
# Epoch  60 | Loss: 1.0951
# 샘플 생성: 가을 하늘 세
# 로궁 이 랑하이이을 마 듯마 듯
# 화무 가강한 남
# 람 전 저 보라 대화려 삼천리 화 삼천
# --------------------------------------------------------------------------------
# Epoch  80 | Loss: 0.5249
# 샘플 생성: 가을 하늘 공대한으로 충 길이 보상하이 사람 사랑사 우나사화 두른 가을 하세
# 무 화려 람 록세
# 괴우리
# --------------------------------------------------------------------------------
# Epoch 100 | Loss: 0.2510
# 샘플 생성: 가을 하늘 저은 우나무 우하세
# 남산 달람 마 닳닳
# 사은 즐서 우리 일세
# 무궁화 삼천리 화려 강산
# 대한
# --------------------------------------------------------------------------------
# Epoch 120 | Loss: 0.1436
# 샘플 생성: 가을 하늘 공활한데
# 높고 구름 저
# 대 삼천리
# 한으로 하괴람 보하사
# 사우 닳른라 불에 으로가성슴 른
# --------------------------------------------------------------------------------
# Epoch 140 | Loss: 0.0983
# 샘플 생성: 가을 하늘 두산
# 바 대이사 없일세
# 무 공과 무궁화 삼천리 화과 불일하세
# 무닳이 천리 화려 강산
# 대한
# --------------------------------------------------------------------------------
# Epoch 160 | Loss: 0.0755
# 샘플 생성: 가을 하늘 공우하세
# 무궁 화려 강산
# 대한으로 길이 마
# 밝은 우리 기일세
# 무궁화 구 삼천리 불함은 우리
# --------------------------------------------------------------------------------
# Epoch 180 | Loss: 0.0621
# 샘플 생성: 가을 하늘 서리산 닳세
# 무우 슴  서리세
# 무  없이 우리나 맘으로 하늘철여
# 기 대한고 른 이과 보전하
# --------------------------------------------------------------------------------
# Epoch 200 | Loss: 0.0534
# 샘플 생성: 가을 하늘 세
# 무 이 삼천리 기상일세
# 무궁화 삼천리 불남대한 사람 대한으로 길이 보하세
# 리 사무궁화
# --------------------------------------------------------------------------------
# Epoch 220 | Loss: 0.0472
# 샘플 생성: 가을 하늘 공한으로 충성을 다하여
# 괴로우나 즐거우나 나라 사랑하을 하늘로 공활한데 높고 구름
#  남 강
# --------------------------------------------------------------------------------
# Epoch 240 | Loss: 0.0428
# 샘플 생성: 가을 하늘 즐산
# 대한으로 길이 보전하세
# 무궁화 삼천리 화려 강산
# 대한으로 길이 보전하세
# 남산 위에 저
# --------------------------------------------------------------------------------
# Epoch 260 | Loss: 0.0394
# 샘플 생성: 가을 하늘 세
# 동해물과 백두산이 마르고 닳도록
# 편 보우리나라 만세
# 무 철을 화려 하사대한 사람 대한으
# --------------------------------------------------------------------------------
# Epoch 280 | Loss: 0.0367
# 샘플 생성: 가을 하늘 공활한데 높고 구
# 하 이 기상일세
# 무궁화 삼천리 화려 강산
# 대한 사람 대한으로 길이 보전하
# --------------------------------------------------------------------------------
